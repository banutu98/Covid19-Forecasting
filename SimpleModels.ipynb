# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from scipy.optimize import curve_fit

# %%
DATA_DIR = 'data'
OUTPUT_FILE = 'submission.csv'
TRAIN_SEQ_SIZE = 62
TEST_SEQ_SIZE = 43

def extract_days_fist_infection(data):
    data['Confirmed>0'] = data['ConfirmedCases'] > 0
    data['Days since first infection'] = \
        data.groupby(['Country_Region',
                      'Province_State'])['Confirmed>0'] \
        .cumsum() \
        .astype(int)
    data.drop(columns=['Confirmed>0'], inplace=True)


def load_initial_data():
    train_path = os.path.join(DATA_DIR, 'train.csv')
    test_path = os.path.join(DATA_DIR, 'test.csv')
    train_data, test_data = pd.read_csv(train_path), pd.read_csv(test_path)
    return train_data, test_data


def load_extended_data():
    def date_parser(x):
        return pd.datetime.strptime(x, '%Y-%m-%d')

    train_path = os.path.join(DATA_DIR, 'train.csv')
    test_path = os.path.join(DATA_DIR, 'test.csv')
    labeled = pd.read_csv(train_path, parse_dates=['Date'],
                          date_parser=date_parser, index_col='Date')
    unlabeled = pd.read_csv(test_path, parse_dates=['Date'],
                            date_parser=date_parser, index_col='Date')
    labeled['Province_State'] = labeled['Province_State'].fillna('<placeholder>')
    unlabeled['Province_State'] = unlabeled['Province_State'].fillna('<placeholder>')
    extract_days_fist_infection(labeled)
    labeled['dummy'] = 1
    labeled['Dummy'] = labeled.groupby(['Country_Region', 'Province_State'])['dummy'].cumsum()
    labeled.drop(columns=['dummy'], inplace=True)
    n_days_training = labeled.groupby(['Country_Region', 'Province_State'])['Id'] \
                             .count() \
                             .max()
    n_days_forecast = unlabeled.groupby(['Country_Region', 'Province_State'])['ForecastId'] \
                               .count() \
                               .max()
    last_days = labeled \
                .groupby(['Country_Region', 'Province_State'])['Days since first infection'] \
                .max()
    last_days = pd.Series(np.repeat(last_days.values, n_days_forecast),
                          index=unlabeled.index)
    unlabeled['dummy'] = 1
    dummy_cumsum = unlabeled \
                   .groupby(['Country_Region', 'Province_State'])['dummy'] \
                   .cumsum()
    continued_days = last_days + dummy_cumsum
    unlabeled['Dummy'] = dummy_cumsum + n_days_training
    unlabeled['Days since first infection'] = continued_days
    unlabeled.drop(columns=['dummy'], inplace=True)
    return labeled, unlabeled

# %%
def convert_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if isinstance(data, list) else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i))
                  for j in range(n_vars)]
    # output sequence
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1))
                      for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1))
                      for j in range(n_vars)]
    # combine all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
def linear_regression(labeled, unlabeled, dummy=False, remove_duplicates=False):
    fit_models = {}
    for key, group in labeled.groupby(['Country_Region', 'Province_State']):
        if dummy:
            X = group['Dummy']
            y = group[['ConfirmedCases', 'Fatalities']]
        else:
            if remove_duplicates:
                unique_days = len(group['Days since first infection'].drop_duplicates(keep='last'))
                start_idx = len(group) - unique_days
            else:
                start_idx = 0
            X = group['Days since first infection'][start_idx:]
            y = group[['ConfirmedCases', 'Fatalities']][start_idx:]
        X = X.values.reshape(-1, 1)
        y = y.values
        model = LinearRegression()
        fit_models[key] = model.fit(X, y)
        print('linear regression => (%s, %s)' % (key[0], key[1]))
    predictions = []
    for key, group in unlabeled.groupby(['Country_Region', 'Province_State']):
        if dummy:
            X = group['Dummy']
        else:
            X = group['Days since first infection']
        X = X.values.reshape(-1, 1)
        predictions.append(fit_models[key].predict(X))
    predictions = np.vstack(predictions)
    predictionsdf = pd.DataFrame(columns=['ForecastId', 'ConfirmedCases', 'Fatalities'])
    predictionsdf['ForecastId'] = unlabeled['ForecastId']
    predictionsdf[['ConfirmedCases', 'Fatalities']] = predictions
    predictionsdf[['ConfirmedCases', 'Fatalities']] = predictionsdf[['ConfirmedCases', 'Fatalities']].astype(int)
    return predictionsdf

# %%
def polynomial_regression(labeled, unlabeled, dummy=False, degree=4,
                          remove_duplicates=False):
    fit_models = {}
    for key, group in labeled.groupby(['Country_Region', 'Province_State']):
        if dummy:
            X = group['Dummy']
            y = group[['ConfirmedCases', 'Fatalities']]
        else:
            if remove_duplicates:
                unique_days = len(group['Days since first infection'].drop_duplicates(keep='last'))
                start_idx = len(group) - unique_days
            else:
                start_idx = 0
            X = group['Days since first infection'][start_idx:]
            y = group[['ConfirmedCases', 'Fatalities']][start_idx:]
        X = X.values.reshape(-1, 1)
        y = y.values
        poly_features = PolynomialFeatures(degree=degree)
        X = poly_features.fit_transform(X)
        model = LinearRegression()
        fit_models[key] = model.fit(X, y)
        print('polynomial regression => (%s, %s)' % (key[0], key[1]))
    predictions = []
    for key, group in unlabeled.groupby(['Country_Region', 'Province_State']):
        if dummy:
            X = group['Dummy']
        else:
            X = group['Days since first infection']
        X = X.values.reshape(-1, 1)
        poly_features = PolynomialFeatures(degree=degree)
        X = poly_features.fit_transform(X)
        predictions.append(fit_models[key].predict(X))
    predictions = np.vstack(predictions)
    predictionsdf = pd.DataFrame(columns=['ForecastId', 'ConfirmedCases', 'Fatalities'])
    predictionsdf['ForecastId'] = unlabeled['ForecastId']
    predictionsdf[['ConfirmedCases', 'Fatalities']] = predictions
    predictionsdf[['ConfirmedCases', 'Fatalities']] = predictionsdf[['ConfirmedCases', 'Fatalities']].astype(int)
    return predictionsdf

# %%
def sigmoid(X, M, beta, alpha):
    return M / (1 + np.exp(-beta * (X - alpha)))

def sigmoid_regression(labeled, unlabeled, dummy=False,
                       remove_duplicates=False):
    fit_models = {}
    for key, group in labeled.groupby(['Country_Region', 'Province_State']):
        if dummy:
            X = group['Dummy']
            y = group[['ConfirmedCases', 'Fatalities']]
        else:
            if remove_duplicates:
                unique_days = len(group['Days since first infection'].drop_duplicates(keep='last'))
                start_idx = len(group) - unique_days
            else:
                start_idx = 0
            X = group['Days since first infection'][start_idx:]
            y = group[['ConfirmedCases', 'Fatalities']][start_idx:]
        y = y.values
        y_c = y[:, 0]
        y_f = y[:, 1]
        try:
            popt, pcov = curve_fit(sigmoid, X, y_c,
                                   maxfev=15000,
                                   p0=[1000, 0.25, 100])
            model_c = popt
            popt, pcov = curve_fit(sigmoid, X, y_f,
                                   maxfev=15000,
                                   p0=[1000, 0.25, 100])
            model_f = popt
            fit_models[key] = {'cases': model_c, 'fatalities': model_f}
            print('sigmoid regression => (%s, %s)' % (key[0], key[1]))
        except RuntimeError as e:
            print(e.args[0])
            print('fitting linear regression model instead')
            X = X.values.reshape(-1, 1)
            lin_model = LinearRegression()
            fit_model = lin_model.fit(X, y)
            fit_models[key] = fit_model
            print('linear regression => (%s, %s)' % (key[0], key[1]))
    predictions = []
    for key, group in unlabeled.groupby(['Country_Region', 'Province_State']):
        if dummy:
            X = group['Dummy']
        else:
            X = group['Days since first infection']
        X = X.values
        if isinstance(fit_models[key], LinearRegression):
            X = X.reshape(-1, 1)
            y_pred = fit_models[key].predict(X)
        else:
            c_params = fit_models[key]['cases']
            f_params = fit_models[key]['fatalities']
            y_pred = np.hstack([sigmoid(X, *c_params).reshape(-1, 1),
                               sigmoid(X, *f_params).reshape(-1, 1)])
        predictions.append(y_pred)
    predictions = np.vstack(predictions)
    predictionsdf = pd.DataFrame(columns=['ForecastId', 'ConfirmedCases', 'Fatalities'])
    predictionsdf['ForecastId'] = unlabeled['ForecastId']
    predictionsdf[['ConfirmedCases', 'Fatalities']] = predictions
    predictionsdf[['ConfirmedCases', 'Fatalities']] = predictionsdf[['ConfirmedCases', 'Fatalities']].astype(int)
    return predictionsdf

# %%
def get_submissions(model_name, dummy_vars=False, poly_degree=4,
                    remove_duplicates=False):
    model = model_name.lower()
    if model_name == 'linreg':
        linear_regression(labeled, unlabeled,
                          dummy=dummy_vars,
                          remove_duplicates=remove_duplicates).to_csv('submission.csv',
                                                                      index=False)
    elif model == 'polyreg':
        polynomial_regression(labeled, unlabeled,
                              dummy=dummy_vars,
                              degree=poly_degree,
                              remove_duplicates=remove_duplicates).to_csv('submission.csv',
                                                                          index=False)
    elif model == 'sigmoid':
        sigmoid_regression(labeled, unlabeled,
                           dummy=dummy_vars,
                           remove_duplicates=remove_duplicates).to_csv('submission.csv',
                                                                       index=False)
    else:
        raise NotImplemented(f'{model} not implemented.')

# %%
labeled, unlabeled = load_extended_data()
get_submissions('sigmoid', dummy_vars=False, poly_degree=2,
                remove_duplicates=True)
# Out:
# /home/klaus/.pyenv/versions/3.7.5/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:25: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
# /home/klaus/.pyenv/versions/3.7.5/envs/mlenv/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# sigmoid regression => (Afghanistan, <placeholder>)
# sigmoid regression => (Albania, <placeholder>)
# sigmoid regression => (Algeria, <placeholder>)
# sigmoid regression => (Andorra, <placeholder>)
# sigmoid regression => (Angola, <placeholder>)
# sigmoid regression => (Antigua and Barbuda, <placeholder>)
# sigmoid regression => (Argentina, <placeholder>)
# /home/klaus/.pyenv/versions/3.7.5/envs/mlenv/lib/python3.7/site-packages/scipy/optimize/minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# sigmoid regression => (Armenia, <placeholder>)
# sigmoid regression => (Australia, Australian Capital Territory)
# sigmoid regression => (Australia, New South Wales)
# sigmoid regression => (Australia, Northern Territory)
# sigmoid regression => (Australia, Queensland)
# sigmoid regression => (Australia, South Australia)
# sigmoid regression => (Australia, Tasmania)
# sigmoid regression => (Australia, Victoria)
# sigmoid regression => (Australia, Western Australia)
# sigmoid regression => (Austria, <placeholder>)
# sigmoid regression => (Azerbaijan, <placeholder>)
# sigmoid regression => (Bahamas, <placeholder>)
# sigmoid regression => (Bahrain, <placeholder>)
# sigmoid regression => (Bangladesh, <placeholder>)
# sigmoid regression => (Barbados, <placeholder>)
# sigmoid regression => (Belarus, <placeholder>)
# sigmoid regression => (Belgium, <placeholder>)
# sigmoid regression => (Belize, <placeholder>)
# sigmoid regression => (Benin, <placeholder>)
# sigmoid regression => (Bhutan, <placeholder>)
# sigmoid regression => (Bolivia, <placeholder>)
# sigmoid regression => (Bosnia and Herzegovina, <placeholder>)
# sigmoid regression => (Botswana, <placeholder>)
# sigmoid regression => (Brazil, <placeholder>)
# sigmoid regression => (Brunei, <placeholder>)
# sigmoid regression => (Bulgaria, <placeholder>)
# sigmoid regression => (Burkina Faso, <placeholder>)
# sigmoid regression => (Burma, <placeholder>)
# sigmoid regression => (Burundi, <placeholder>)
# sigmoid regression => (Cabo Verde, <placeholder>)
# sigmoid regression => (Cambodia, <placeholder>)
# sigmoid regression => (Cameroon, <placeholder>)
# sigmoid regression => (Canada, Alberta)
# sigmoid regression => (Canada, British Columbia)
# sigmoid regression => (Canada, Manitoba)
# sigmoid regression => (Canada, New Brunswick)
# sigmoid regression => (Canada, Newfoundland and Labrador)
# sigmoid regression => (Canada, Northwest Territories)
# sigmoid regression => (Canada, Nova Scotia)
# sigmoid regression => (Canada, Ontario)
# sigmoid regression => (Canada, Prince Edward Island)
# sigmoid regression => (Canada, Quebec)
# sigmoid regression => (Canada, Saskatchewan)
# sigmoid regression => (Canada, Yukon)
# sigmoid regression => (Central African Republic, <placeholder>)
# sigmoid regression => (Chad, <placeholder>)
# sigmoid regression => (Chile, <placeholder>)
# sigmoid regression => (China, Anhui)
# sigmoid regression => (China, Beijing)
# sigmoid regression => (China, Chongqing)
# sigmoid regression => (China, Fujian)
# sigmoid regression => (China, Gansu)
# sigmoid regression => (China, Guangdong)
# sigmoid regression => (China, Guangxi)
# sigmoid regression => (China, Guizhou)
# sigmoid regression => (China, Hainan)
# sigmoid regression => (China, Hebei)
# sigmoid regression => (China, Heilongjiang)
# sigmoid regression => (China, Henan)
# sigmoid regression => (China, Hong Kong)
# sigmoid regression => (China, Hubei)
# sigmoid regression => (China, Hunan)
# sigmoid regression => (China, Inner Mongolia)
# sigmoid regression => (China, Jiangsu)
# sigmoid regression => (China, Jiangxi)
# sigmoid regression => (China, Jilin)
# sigmoid regression => (China, Liaoning)
# sigmoid regression => (China, Macau)
# sigmoid regression => (China, Ningxia)
# sigmoid regression => (China, Qinghai)
# sigmoid regression => (China, Shaanxi)
# sigmoid regression => (China, Shandong)
# sigmoid regression => (China, Shanghai)
# sigmoid regression => (China, Shanxi)
# sigmoid regression => (China, Sichuan)
# sigmoid regression => (China, Tianjin)
# sigmoid regression => (China, Tibet)
# sigmoid regression => (China, Xinjiang)
# sigmoid regression => (China, Yunnan)
# sigmoid regression => (China, Zhejiang)
# sigmoid regression => (Colombia, <placeholder>)
# sigmoid regression => (Congo (Brazzaville), <placeholder>)
# sigmoid regression => (Congo (Kinshasa), <placeholder>)
# sigmoid regression => (Costa Rica, <placeholder>)
# sigmoid regression => (Cote d'Ivoire, <placeholder>)
# sigmoid regression => (Croatia, <placeholder>)
# sigmoid regression => (Cuba, <placeholder>)
# sigmoid regression => (Cyprus, <placeholder>)
# sigmoid regression => (Czechia, <placeholder>)
# sigmoid regression => (Denmark, <placeholder>)
# sigmoid regression => (Denmark, Faroe Islands)
# sigmoid regression => (Denmark, Greenland)
# sigmoid regression => (Diamond Princess, <placeholder>)
# Optimal parameters not found: Number of calls to function has reached maxfev = 15000.
# fitting linear regression model instead
# linear regression => (Djibouti, <placeholder>)
# sigmoid regression => (Dominica, <placeholder>)
# /home/klaus/.pyenv/versions/3.7.5/envs/mlenv/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/klaus/.pyenv/versions/3.7.5/envs/mlenv/lib/python3.7/site-packages/scipy/optimize/minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# sigmoid regression => (Dominican Republic, <placeholder>)
# sigmoid regression => (Ecuador, <placeholder>)
# sigmoid regression => (Egypt, <placeholder>)
# sigmoid regression => (El Salvador, <placeholder>)
# sigmoid regression => (Equatorial Guinea, <placeholder>)
# sigmoid regression => (Eritrea, <placeholder>)
# sigmoid regression => (Estonia, <placeholder>)
# sigmoid regression => (Eswatini, <placeholder>)
# sigmoid regression => (Ethiopia, <placeholder>)
# sigmoid regression => (Fiji, <placeholder>)
# sigmoid regression => (Finland, <placeholder>)
# sigmoid regression => (France, <placeholder>)
# sigmoid regression => (France, French Guiana)
# sigmoid regression => (France, French Polynesia)
# sigmoid regression => (France, Guadeloupe)
# sigmoid regression => (France, Martinique)
# sigmoid regression => (France, Mayotte)
# sigmoid regression => (France, New Caledonia)
# sigmoid regression => (France, Reunion)
# sigmoid regression => (France, Saint Barthelemy)
# sigmoid regression => (France, Saint Pierre and Miquelon)
# sigmoid regression => (France, St Martin)
# sigmoid regression => (Gabon, <placeholder>)
# sigmoid regression => (Gambia, <placeholder>)
# sigmoid regression => (Georgia, <placeholder>)
# sigmoid regression => (Germany, <placeholder>)
# sigmoid regression => (Ghana, <placeholder>)
# sigmoid regression => (Greece, <placeholder>)
# sigmoid regression => (Grenada, <placeholder>)
# sigmoid regression => (Guatemala, <placeholder>)
# sigmoid regression => (Guinea, <placeholder>)
# sigmoid regression => (Guinea-Bissau, <placeholder>)
# sigmoid regression => (Guyana, <placeholder>)
# sigmoid regression => (Haiti, <placeholder>)
# sigmoid regression => (Holy See, <placeholder>)
# sigmoid regression => (Honduras, <placeholder>)
# sigmoid regression => (Hungary, <placeholder>)
# sigmoid regression => (Iceland, <placeholder>)
# sigmoid regression => (India, <placeholder>)
# sigmoid regression => (Indonesia, <placeholder>)
# sigmoid regression => (Iran, <placeholder>)
# sigmoid regression => (Iraq, <placeholder>)
# sigmoid regression => (Ireland, <placeholder>)
# sigmoid regression => (Israel, <placeholder>)
# sigmoid regression => (Italy, <placeholder>)
# sigmoid regression => (Jamaica, <placeholder>)
# sigmoid regression => (Japan, <placeholder>)
# sigmoid regression => (Jordan, <placeholder>)
# sigmoid regression => (Kazakhstan, <placeholder>)
# sigmoid regression => (Kenya, <placeholder>)
# sigmoid regression => (Korea, South, <placeholder>)
# sigmoid regression => (Kosovo, <placeholder>)
# sigmoid regression => (Kuwait, <placeholder>)
# sigmoid regression => (Kyrgyzstan, <placeholder>)
# sigmoid regression => (Laos, <placeholder>)
# sigmoid regression => (Latvia, <placeholder>)
# sigmoid regression => (Lebanon, <placeholder>)
# sigmoid regression => (Liberia, <placeholder>)
# sigmoid regression => (Libya, <placeholder>)
# sigmoid regression => (Liechtenstein, <placeholder>)
# sigmoid regression => (Lithuania, <placeholder>)
# sigmoid regression => (Luxembourg, <placeholder>)
# sigmoid regression => (MS Zaandam, <placeholder>)
# sigmoid regression => (Madagascar, <placeholder>)
# sigmoid regression => (Malawi, <placeholder>)
# sigmoid regression => (Malaysia, <placeholder>)
# sigmoid regression => (Maldives, <placeholder>)
# sigmoid regression => (Mali, <placeholder>)
# sigmoid regression => (Malta, <placeholder>)
# sigmoid regression => (Mauritania, <placeholder>)
# sigmoid regression => (Mauritius, <placeholder>)
# sigmoid regression => (Mexico, <placeholder>)
# sigmoid regression => (Moldova, <placeholder>)
# sigmoid regression => (Monaco, <placeholder>)
# sigmoid regression => (Mongolia, <placeholder>)
# sigmoid regression => (Montenegro, <placeholder>)
# sigmoid regression => (Morocco, <placeholder>)
# sigmoid regression => (Mozambique, <placeholder>)
# sigmoid regression => (Namibia, <placeholder>)
# sigmoid regression => (Nepal, <placeholder>)
# sigmoid regression => (Netherlands, <placeholder>)
# sigmoid regression => (Netherlands, Aruba)
# sigmoid regression => (Netherlands, Bonaire, Sint Eustatius and Saba)
# sigmoid regression => (Netherlands, Curacao)
# sigmoid regression => (Netherlands, Sint Maarten)
# sigmoid regression => (New Zealand, <placeholder>)
# sigmoid regression => (Nicaragua, <placeholder>)
# sigmoid regression => (Niger, <placeholder>)
# sigmoid regression => (Nigeria, <placeholder>)
# sigmoid regression => (North Macedonia, <placeholder>)
# sigmoid regression => (Norway, <placeholder>)
# sigmoid regression => (Oman, <placeholder>)
# sigmoid regression => (Pakistan, <placeholder>)
# sigmoid regression => (Panama, <placeholder>)
# sigmoid regression => (Papua New Guinea, <placeholder>)
# sigmoid regression => (Paraguay, <placeholder>)
# sigmoid regression => (Peru, <placeholder>)
# sigmoid regression => (Philippines, <placeholder>)
# sigmoid regression => (Poland, <placeholder>)
# sigmoid regression => (Portugal, <placeholder>)
# sigmoid regression => (Qatar, <placeholder>)
# sigmoid regression => (Romania, <placeholder>)
# sigmoid regression => (Russia, <placeholder>)
# sigmoid regression => (Rwanda, <placeholder>)
# sigmoid regression => (Saint Kitts and Nevis, <placeholder>)
# sigmoid regression => (Saint Lucia, <placeholder>)
# sigmoid regression => (Saint Vincent and the Grenadines, <placeholder>)
# sigmoid regression => (San Marino, <placeholder>)
# sigmoid regression => (Sao Tome and Principe, <placeholder>)
# sigmoid regression => (Saudi Arabia, <placeholder>)
# sigmoid regression => (Senegal, <placeholder>)
# sigmoid regression => (Serbia, <placeholder>)
# sigmoid regression => (Seychelles, <placeholder>)
# sigmoid regression => (Sierra Leone, <placeholder>)
# sigmoid regression => (Singapore, <placeholder>)
# sigmoid regression => (Slovakia, <placeholder>)
# sigmoid regression => (Slovenia, <placeholder>)
# sigmoid regression => (Somalia, <placeholder>)
# sigmoid regression => (South Africa, <placeholder>)
# sigmoid regression => (South Sudan, <placeholder>)
# sigmoid regression => (Spain, <placeholder>)
# sigmoid regression => (Sri Lanka, <placeholder>)
# sigmoid regression => (Sudan, <placeholder>)
# sigmoid regression => (Suriname, <placeholder>)
# sigmoid regression => (Sweden, <placeholder>)
# sigmoid regression => (Switzerland, <placeholder>)
# sigmoid regression => (Syria, <placeholder>)
# sigmoid regression => (Taiwan*, <placeholder>)
# sigmoid regression => (Tanzania, <placeholder>)
# sigmoid regression => (Thailand, <placeholder>)
# sigmoid regression => (Timor-Leste, <placeholder>)
# sigmoid regression => (Togo, <placeholder>)
# sigmoid regression => (Trinidad and Tobago, <placeholder>)
# sigmoid regression => (Tunisia, <placeholder>)
# sigmoid regression => (Turkey, <placeholder>)
# sigmoid regression => (US, Alabama)
# sigmoid regression => (US, Alaska)
# sigmoid regression => (US, Arizona)
# sigmoid regression => (US, Arkansas)
# sigmoid regression => (US, California)
# sigmoid regression => (US, Colorado)
# sigmoid regression => (US, Connecticut)
# sigmoid regression => (US, Delaware)
# sigmoid regression => (US, District of Columbia)
# sigmoid regression => (US, Florida)
# sigmoid regression => (US, Georgia)
# sigmoid regression => (US, Guam)
# sigmoid regression => (US, Hawaii)
# sigmoid regression => (US, Idaho)
# sigmoid regression => (US, Illinois)
# sigmoid regression => (US, Indiana)
# sigmoid regression => (US, Iowa)
# sigmoid regression => (US, Kansas)
# sigmoid regression => (US, Kentucky)
# sigmoid regression => (US, Louisiana)
# sigmoid regression => (US, Maine)
# sigmoid regression => (US, Maryland)
# sigmoid regression => (US, Massachusetts)
# sigmoid regression => (US, Michigan)
# sigmoid regression => (US, Minnesota)
# sigmoid regression => (US, Mississippi)
# sigmoid regression => (US, Missouri)
# sigmoid regression => (US, Montana)
# sigmoid regression => (US, Nebraska)
# sigmoid regression => (US, Nevada)
# sigmoid regression => (US, New Hampshire)
# sigmoid regression => (US, New Jersey)
# sigmoid regression => (US, New Mexico)
# sigmoid regression => (US, New York)
# sigmoid regression => (US, North Carolina)
# sigmoid regression => (US, North Dakota)
# sigmoid regression => (US, Ohio)
# sigmoid regression => (US, Oklahoma)
# sigmoid regression => (US, Oregon)
# sigmoid regression => (US, Pennsylvania)
# sigmoid regression => (US, Puerto Rico)
# sigmoid regression => (US, Rhode Island)
# sigmoid regression => (US, South Carolina)
# sigmoid regression => (US, South Dakota)
# sigmoid regression => (US, Tennessee)
# sigmoid regression => (US, Texas)
# sigmoid regression => (US, Utah)
# sigmoid regression => (US, Vermont)
# sigmoid regression => (US, Virgin Islands)
# sigmoid regression => (US, Virginia)
# sigmoid regression => (US, Washington)
# sigmoid regression => (US, West Virginia)
# sigmoid regression => (US, Wisconsin)
# sigmoid regression => (US, Wyoming)
# sigmoid regression => (Uganda, <placeholder>)
# sigmoid regression => (Ukraine, <placeholder>)
# sigmoid regression => (United Arab Emirates, <placeholder>)
# sigmoid regression => (United Kingdom, <placeholder>)
# sigmoid regression => (United Kingdom, Anguilla)
# sigmoid regression => (United Kingdom, Bermuda)
# sigmoid regression => (United Kingdom, British Virgin Islands)
# sigmoid regression => (United Kingdom, Cayman Islands)
# sigmoid regression => (United Kingdom, Channel Islands)
# sigmoid regression => (United Kingdom, Falkland Islands (Malvinas))
# sigmoid regression => (United Kingdom, Gibraltar)
# sigmoid regression => (United Kingdom, Isle of Man)
# sigmoid regression => (United Kingdom, Montserrat)
# sigmoid regression => (United Kingdom, Turks and Caicos Islands)
# sigmoid regression => (Uruguay, <placeholder>)
# sigmoid regression => (Uzbekistan, <placeholder>)
# sigmoid regression => (Venezuela, <placeholder>)
# sigmoid regression => (Vietnam, <placeholder>)
# sigmoid regression => (West Bank and Gaza, <placeholder>)
# sigmoid regression => (Western Sahara, <placeholder>)
# sigmoid regression => (Zambia, <placeholder>)
# sigmoid regression => (Zimbabwe, <placeholder>)
